# %%
import pandas as pd
import os

real_videos_folder = "C:\\Users\\Odwitiyo\\Downloads\\deepfake_dataset\\deepfake_dataset\\train\\real"
fake_videos_folder = "C:\\Users\\Odwitiyo\\Downloads\\deepfake_dataset\\deepfake_dataset\\train\\fake"

video_data = []

if os.path.exists(real_videos_folder):
    for filename in os.listdir(real_videos_folder):
        if filename.endswith('.mp4') or filename.endswith('.avi'): 
            video_path = os.path.join(real_videos_folder, filename)
            video_data.append({'video_path': video_path, 'label': 1})
    print(f"Processed 'real' videos from {real_videos_folder}")
else:
    print(f"Warning: 'real' folder not found at {real_videos_folder}")
    print(f"Expected path: {real_videos_folder}")

if os.path.exists(fake_videos_folder):
    for filename in os.listdir(fake_videos_folder):
        if filename.endswith('.mp4') or filename.endswith('.avi'): 
            video_path = os.path.join(fake_videos_folder, filename)
            video_data.append({'video_path': video_path, 'label': 0})
    print(f"Processed 'fake' videos from {fake_videos_folder}")
else:
    print(f"Warning: 'fake' folder not found at {fake_videos_folder}")
    print(f"Expected path: {fake_videos_folder}")

df = pd.DataFrame(video_data)

df['resnet_features'] = None 

print("\nInitial DataFrame created:")
print(df.head())

print(f"\nTotal videos found: {len(df)}")
print(f"Number of 'real' videos: {len(df[df['label'] == 1])}")
print(f"Number of 'fake' videos: {len(df[df['label'] == 0])}")
# Out:
# Processed 'real' videos from C:\Users\Odwitiyo\Downloads\deepfake_dataset\deepfake_dataset\train\real
# Processed 'fake' videos from C:\Users\Odwitiyo\Downloads\deepfake_dataset\deepfake_dataset\train\fake
#
# Initial DataFrame created:
#                                           video_path  label resnet_features
# 0  C:\Users\Odwitiyo\Downloads\deepfake_dataset\d...      1            None
# 1  C:\Users\Odwitiyo\Downloads\deepfake_dataset\d...      1            None
# 2  C:\Users\Odwitiyo\Downloads\deepfake_dataset\d...      1            None
# 3  C:\Users\Odwitiyo\Downloads\deepfake_dataset\d...      1            None
# 4  C:\Users\Odwitiyo\Downloads\deepfake_dataset\d...      1            None
#
# Total videos found: 360
# Number of 'real' videos: 180
# Number of 'fake' videos: 180

# %%
import tensorflow as tf
import numpy as np
import cv2

try:
    base_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, pooling='avg')
    print("ResNet50 model loaded successfully.")
except Exception as e:
    print(f"Error loading ResNet50 model: {e}")
    print("Please ensure you have a stable internet connection to download weights.")

frames_to_extract_per_video = 40 

def extract_resnet_features(video_path, model, num_frames=10):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Warning: Could not open video file {video_path}")
        return None
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total_frames <= 0:
        print(f"Warning: Could not get frame count for {video_path}")
        cap.release()
        return None
    if total_frames < num_frames:
        frame_indices = np.arange(total_frames)
    else:
        frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    frame_features = []
    for i in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, i)
        ret, frame = cap.read()
        if not ret:
            continue
        img = cv2.resize(frame, (224, 224))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = np.expand_dims(img, axis=0) 
        img = tf.keras.applications.resnet50.preprocess_input(img) 
        features = model.predict(img)
        frame_features.append(features.flatten()) 
    cap.release()
    if not frame_features:
        return None
    aggregated_features = np.mean(frame_features, axis=0)
    return aggregated_features
df['resnet_features'] = None
for index, row in df.iterrows():
    video_path = row['video_path']
    features = extract_resnet_features(video_path, base_model, num_frames=frames_to_extract_per_video)
    if features is not None:
        df.at[index, 'resnet_features'] = features
    else:
        df.at[index, 'resnet_features'] = np.nan 
    print(f"Processed {video_path}")

print("\nDataFrame with ResNet features:")
print(df.head())

df.to_pickle('C:\\Users\\Odwitiyo\\Downloads\\dataframe_with_resnet_features.pkl')

# %%
import pandas as pd
import os

test_real_videos_folder = "C:\\Users\\Odwitiyo\\Downloads\\deepfake_dataset\\deepfake_dataset\\test\\real"  
test_fake_videos_folder = "C:\\Users\\Odwitiyo\\Downloads\\deepfake_dataset\\deepfake_dataset\\test\\fake"  

test_video_data = []

if os.path.exists(test_real_videos_folder):
    for filename in os.listdir(test_real_videos_folder):
        if filename.endswith('.mp4') or filename.endswith('.avi'): 
            video_path = os.path.join(test_real_videos_folder, filename)
            test_video_data.append({'video_path': video_path, 'label': 1})
    print(f"Processed 'real' test videos from {test_real_videos_folder}")
else:
    print(f"Warning: 'real' test folder not found at {test_real_videos_folder}")
    print(f"Expected path: {test_real_videos_folder}")

if os.path.exists(test_fake_videos_folder):
    for filename in os.listdir(test_fake_videos_folder):
        if filename.endswith('.mp4') or filename.endswith('.avi'): 
            video_path = os.path.join(test_fake_videos_folder, filename)
            test_video_data.append({'video_path': video_path, 'label': 0})
    print(f"Processed 'fake' test videos from {test_fake_videos_folder}")
else:
    print(f"Warning: 'fake' test folder not found at {test_fake_videos_folder}")
    print(f"Expected path: {test_fake_videos_folder}")

df_test = pd.DataFrame(test_video_data)

df_test['resnet_features'] = None 
for index, row in df_test.iterrows():
    video_path = row['video_path']
    features = extract_resnet_features(video_path, base_model, num_frames=frames_to_extract_per_video)
    if features is not None:
        df_test.at[index, 'resnet_features'] = features
    else:
        df_test.at[index, 'resnet_features'] = np.nan 
    print(f"Processed {video_path}")
print("\nInitial Test DataFrame created:")
print(df_test.head())

print(f"\nTotal test videos found: {len(df_test)}")
print(f"Number of 'real' test videos: {len(df_test[df_test['label'] == 1])}")
print(f"Number of 'fake' test videos: {len(df_test[df_test['label'] == 0])}")

df_test.to_pickle('C:\\Users\\Odwitiyo\\Downloads\\test_with_resnet_features.pkl')

# %%
import pandas as pd
df = pd.read_pickle("C:\\Users\\Odwitiyo\\Downloads\\dataframe_with_resnet_features.pkl")
df_test = pd.read_pickle("C:\\Users\\Odwitiyo\\Downloads\\test_with_resnet_features.pkl")

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import tensorflow as tf 

def prepare_data_for_standard_autoencoder(dataframe, column_name='resnet_features'):
    cleaned_df = dataframe.dropna(subset=[column_name, 'label'])
    features_raw = cleaned_df[column_name].tolist()
    labels_raw = cleaned_df['label'].tolist()
    if not features_raw:
        print(f"No valid features found in '{column_name}' column.")
        return np.array([]), np.array([]), 0
    feature_dimension = 0
    for feature_list in features_raw:
        if isinstance(feature_list, (list, np.ndarray)):
            feature_dimension = len(feature_list)
            print(f"Determined feature dimension from data: {feature_dimension}")
            break
    if feature_dimension == 0:
        print("Could not determine feature dimension from data.")
        return np.array([]), np.array([]), 0
    processed_features = []
    processed_labels = []
    for i, feature_list in enumerate(features_raw):
        if isinstance(feature_list, (list, np.ndarray)) and len(feature_list) == feature_dimension:
            processed_features.append(np.array(feature_list))
            processed_labels.append(labels_raw[i])
        else:
            print(f"Skipping invalid feature entry at index {i}.")
    if not processed_features:
        print("No valid features found after processing.")
        return np.array([]), np.array([]), 0
    else:
        return np.array(processed_features), np.array(processed_labels), feature_dimension
    
def remove_outliers_percentile(data, lower_percentile=1, upper_percentile=99):
    if data.shape[0] == 0:
        print("Input data to remove_outliers_percentile is empty.")
        return data
    print(f"Attempting to remove outliers using percentile method ({lower_percentile}-{upper_percentile})...")
    lower_bounds = np.percentile(data, lower_percentile, axis=0)
    upper_bounds = np.percentile(data, upper_percentile, axis=0)
    is_within_bounds = (data >= lower_bounds) & (data <= upper_bounds)
    non_outlier_mask = np.all(is_within_bounds, axis=1)
    print(f"Original data shape: {data.shape}")
    print(f"Number of samples flagged as outliers: {np.sum(~non_outlier_mask)}")
    print(f"Shape after removing outliers: {data[non_outlier_mask].shape}")
    return data[non_outlier_mask]

X_real_train_full, y_real_train_full, feature_dimension = prepare_data_for_standard_autoencoder(df[df['label'] == 1], column_name='resnet_features')

if X_real_train_full.shape[0] > 0 and feature_dimension > 0:

    print(f"Shape of real training data for Standard Autoencoder: {X_real_train_full.shape}")
    print(f"Feature Dimension: {feature_dimension}")
    X_real_train_cleaned = remove_outliers_percentile(X_real_train_full, lower_percentile=15, upper_percentile=85)

    if X_real_train_cleaned.shape[0] == 0:
        print("Warning: All real training data removed as outliers.")
        print("Proceeding without outlier removal due to all data being removed.")
        X_real_train_cleaned = X_real_train_full 
        print(f"Using original real training data shape: {X_real_train_cleaned.shape}")
    if X_real_train_cleaned.shape[0] > 0:
        X_real_train, X_real_val = train_test_split(X_real_train_cleaned, test_size=0.2, random_state=42)
        print(f"Real training set size for Autoencoder after outlier handling: {len(X_real_train)}")
        print(f"Real validation set size for Autoencoder after outlier handling: {len(X_real_val)}")

        if feature_dimension > 0:
            input_layer = Input(shape=(feature_dimension,))
            encoded = Dense(128, activation='relu')(input_layer)
            encoded = Dropout(0.2)(encoded)
            encoded = BatchNormalization()(encoded)
            encoded = Dense(64, activation='relu')(encoded)
            encoded = Dropout(0.2)(encoded)
            encoded = BatchNormalization()(encoded)
            encoded = Dense(32, activation='relu')(encoded) 

            decoded = Dense(64, activation='relu')(encoded)
            decoded = BatchNormalization()(decoded)
            decoded = Dense(128, activation='relu')(decoded)
            decoded = BatchNormalization()(decoded)
            output_layer = Dense(feature_dimension, activation='linear')(decoded) 

            autoencoder = Model(inputs=input_layer, outputs=output_layer)

            autoencoder.compile(optimizer=Adam(learning_rate=0.003),
                                loss='mse',
                                metrics=['accuracy','auc'])

            autoencoder.summary()
            if X_real_train.shape[0] > 0:
                history_autoencoder = autoencoder.fit(X_real_train, X_real_train, 
                                                    epochs=2000, 
                                                    batch_size=32,
                                                    validation_data=(X_real_val, X_real_val), 
                                                    verbose=1)
            else:
                print("Cannot train model")

            def calculate_reconstruction_error_std(model, data):
                if data.shape[0] == 0:
                    return np.array([]) 
                reconstructed_data = model.predict(data, verbose=0)
                mse = np.mean(np.power(data - reconstructed_data, 2), axis=1)
                return mse

            X_train_full_scoring, y_train_full_labels, _ = prepare_data_for_standard_autoencoder(
                df, column_name='resnet_features'
            )

            if X_train_full_scoring.shape[0] > 0:
                print("\nCalculating reconstruction errors for training data...")
                train_reconstruction_errors = calculate_reconstruction_error_std(autoencoder, X_train_full_scoring)
                print("Reconstruction errors calculated for training data.")
                
                X_test_scoring, y_test_labels, _ = prepare_data_for_standard_autoencoder(
                    df_test, column_name='resnet_features'
                )

                if X_test_scoring.shape[0] > 0:
                    print("Calculating reconstruction errors for test data...")
                    test_reconstruction_errors = calculate_reconstruction_error_std(autoencoder, X_test_scoring)
                    print("Reconstruction errors calculated for test data.")

                    if y_train_full_labels.shape[0] > 0 and train_reconstruction_errors.shape[0] == y_train_full_labels.shape[0]:
                        plt.figure(figsize=(10, 6))
                        plt.hist(train_reconstruction_errors[y_train_full_labels == 1], bins=50, alpha=0.5, label='Real (Train)')
                        plt.hist(train_reconstruction_errors[y_train_full_labels == 0], bins=50, alpha=0.5, label='Fake (Train)')
                        plt.xlabel("Reconstruction Error (MSE)")
                        plt.ylabel("Frequency")
                        plt.title("Reconstruction Error Distribution - Training Data (for Thresholding)")
                        plt.legend()
                        plt.show()

                        if np.sum(y_train_full_labels == 1) > 0: 
                            real_train_scoring_errors = train_reconstruction_errors[y_train_full_labels == 1]
                            if real_train_scoring_errors.shape[0] > 0:
                                anomaly_threshold = np.percentile(real_train_scoring_errors, 82.5)
                                print(f"\nAnomaly Threshold (95th percentile of real train errors): {anomaly_threshold:.4f}")
                                test_predictions = (test_reconstruction_errors > anomaly_threshold).astype(int) 
                                print("\nAutoencoder-based Deepfake Detection Evaluation on Testing Set:")
                                print("Accuracy:", accuracy_score(y_test_labels, test_predictions))
                                auc_autoencoder_correct = roc_auc_score(y_test_labels, test_reconstruction_errors)
                                print("AUC:", auc_autoencoder_correct)
                                print("\nClassification Report:")
                                print(classification_report(y_test_labels, test_predictions, target_names=['Fake', 'Real']))
                                print("\nConfusion Matrix:")
                                print(confusion_matrix(y_test_labels, test_predictions))
                                fpr_ae, tpr_ae, thresholds_ae = roc_curve(y_test_labels, test_reconstruction_errors)
                                plt.figure(figsize=(8, 6))
                                plt.plot(fpr_ae, tpr_ae, label=f'Autoencoder (AUC = {auc_autoencoder_correct:.2f})')
                                plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
                                plt.xlabel('False Positive Rate')
                                plt.ylabel('True Positive Rate')
                                plt.title('ROC Curve - Standard Autoencoder (Anomaly Detection)')
                                plt.legend()
                                plt.grid(True)
                                plt.show()
                            else:
                                print("Cannot determine threshold: No real samples found in full training data for error calculation.")
                        else:
                            print("Cannot determine threshold: No real samples found in full training data.")
                    else:
                        print("Cannot determine threshold or evaluate performance: Mismatch between training scores and labels.")
                else:
                    print("No valid test data for evaluation.")
            else:
                print("No valid training data for anomaly scoring.")
        else:
            print("Cannot build model: Feature dimension not determined or became zero after processing.")
    else:
        print("Cannot split data or build model: No valid real training data available after outlier handling.")
else:
    print("No valid real training data for Standard Autoencoder training or feature dimension could not be determined.")
# Out:
# --- Starting Standard Autoencoder Workflow (Fixed-Size Feature Vectors) ---
#
# --- Preparing Real Training Data for Standard Autoencoder ---
# Determined feature dimension from data: 2048
# Shape of real training data for Standard Autoencoder: (180, 2048)
# Feature Dimension: 2048
# Attempting to remove outliers using percentile method (15-85)...
# Original data shape: (180, 2048)
# Number of samples flagged as outliers: 180
# Shape after removing outliers: (0, 2048)
# Warning: All real training data removed as outliers.
# Proceeding without outlier removal due to all data being removed.
# Using original real training data shape: (180, 2048)
# Real training set size for Autoencoder after outlier handling: 144
# Real validation set size for Autoencoder after outlier handling: 36
#
# --- Building Standard Autoencoder Model ---
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 2048)           │       264,192 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 548,768 (2.09 MB)
#  Trainable params: 548,000 (2.09 MB)
#  Non-trainable params: 768 (3.00 KB)
# Starting Standard Autoencoder training on real data...
# Epoch 1/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.0000e+00 - auc: 0.4989 - loss: 0.9105 - val_accuracy: 0.0556 - val_auc: 0.5457 - val_loss: 0.8260
# Epoch 2/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0143 - auc: 0.5423 - loss: 0.7779 - val_accuracy: 0.0833 - val_auc: 0.5739 - val_loss: 0.8164
# Epoch 3/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.0992 - auc: 0.6061 - loss: 0.7074 - val_accuracy: 0.0278 - val_auc: 0.5988 - val_loss: 0.8721
# Epoch 4/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1528 - auc: 0.6195 - loss: 0.6514 - val_accuracy: 0.0278 - val_auc: 0.6154 - val_loss: 0.8754
# Epoch 5/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2072 - auc: 0.6470 - loss: 0.5839 - val_accuracy: 0.0278 - val_auc: 0.6537 - val_loss: 0.8353
# Epoch 6/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2705 - auc: 0.6990 - loss: 0.5210 - val_accuracy: 0.1944 - val_auc: 0.7104 - val_loss: 0.7388
# Epoch 7/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3119 - auc: 0.7423 - loss: 0.4486 - val_accuracy: 0.2222 - val_auc: 0.7396 - val_loss: 0.6412
# Epoch 8/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2733 - auc: 0.7701 - loss: 0.3652 - val_accuracy: 0.2222 - val_auc: 0.7771 - val_loss: 0.5359
# Epoch 9/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4023 - auc: 0.8195 - loss: 0.2901 - val_accuracy: 0.2778 - val_auc: 0.7997 - val_loss: 0.4385
# Epoch 10/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3679 - auc: 0.8393 - loss: 0.2320 - val_accuracy: 0.3056 - val_auc: 0.8306 - val_loss: 0.3843
# Epoch 11/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3979 - auc: 0.8571 - loss: 0.1979 - val_accuracy: 0.3333 - val_auc: 0.8464 - val_loss: 0.3390
# Epoch 12/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4298 - auc: 0.8719 - loss: 0.1730 - val_accuracy: 0.3333 - val_auc: 0.8386 - val_loss: 0.2950
# Epoch 13/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4482 - auc: 0.8708 - loss: 0.1624 - val_accuracy: 0.3333 - val_auc: 0.8365 - val_loss: 0.2553
# Epoch 14/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4039 - auc: 0.8574 - loss: 0.1490 - val_accuracy: 0.3611 - val_auc: 0.8461 - val_loss: 0.2375
# Epoch 15/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4453 - auc: 0.8731 - loss: 0.1432 - val_accuracy: 0.3611 - val_auc: 0.8362 - val_loss: 0.2229
# Epoch 16/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4266 - auc: 0.8653 - loss: 0.1398 - val_accuracy: 0.3889 - val_auc: 0.8432 - val_loss: 0.2066
# Epoch 17/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4724 - auc: 0.8776 - loss: 0.1326 - val_accuracy: 0.3889 - val_auc: 0.8453 - val_loss: 0.1911
# Epoch 18/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5242 - auc: 0.8703 - loss: 0.1326 - val_accuracy: 0.5000 - val_auc: 0.8496 - val_loss: 0.1792
# Epoch 19/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4987 - auc: 0.8772 - loss: 0.1289 - val_accuracy: 0.5278 - val_auc: 0.8629 - val_loss: 0.1824
# Epoch 20/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5343 - auc: 0.8845 - loss: 0.1291 - val_accuracy: 0.4722 - val_auc: 0.8631 - val_loss: 0.1707
# Epoch 21/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5807 - auc: 0.8796 - loss: 0.1215 - val_accuracy: 0.5000 - val_auc: 0.8354 - val_loss: 0.1723
# Epoch 22/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5707 - auc: 0.8689 - loss: 0.1240 - val_accuracy: 0.5000 - val_auc: 0.8667 - val_loss: 0.1643
# Epoch 23/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6043 - auc: 0.8790 - loss: 0.1200 - val_accuracy: 0.4722 - val_auc: 0.8470 - val_loss: 0.1668
# Epoch 24/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5716 - auc: 0.8747 - loss: 0.1238 - val_accuracy: 0.5000 - val_auc: 0.8594 - val_loss: 0.1549
# Epoch 25/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6499 - auc: 0.8756 - loss: 0.1256 - val_accuracy: 0.5278 - val_auc: 0.8432 - val_loss: 0.1551
# Epoch 26/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6826 - auc: 0.8645 - loss: 0.1188 - val_accuracy: 0.5833 - val_auc: 0.8522 - val_loss: 0.1575
# Epoch 27/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6970 - auc: 0.8795 - loss: 0.1223 - val_accuracy: 0.5000 - val_auc: 0.8459 - val_loss: 0.1491
# Epoch 28/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5859 - auc: 0.8566 - loss: 0.1312 - val_accuracy: 0.5278 - val_auc: 0.8460 - val_loss: 0.1507
# Epoch 29/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6228 - auc: 0.8714 - loss: 0.1222 - val_accuracy: 0.5000 - val_auc: 0.8471 - val_loss: 0.1555
# Epoch 30/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6626 - auc: 0.8708 - loss: 0.1145 - val_accuracy: 0.5000 - val_auc: 0.8505 - val_loss: 0.1490
# Epoch 31/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6081 - auc: 0.8342 - loss: 0.1365 - val_accuracy: 0.5556 - val_auc: 0.8688 - val_loss: 0.1443
# Epoch 32/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6803 - auc: 0.8734 - loss: 0.1173 - val_accuracy: 0.5278 - val_auc: 0.8532 - val_loss: 0.1512
# Epoch 33/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7115 - auc: 0.8632 - loss: 0.1206 - val_accuracy: 0.5556 - val_auc: 0.8515 - val_loss: 0.1648
# Epoch 34/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6565 - auc: 0.8829 - loss: 0.1139 - val_accuracy: 0.5278 - val_auc: 0.8697 - val_loss: 0.1490
# Epoch 35/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6516 - auc: 0.8640 - loss: 0.1201 - val_accuracy: 0.5833 - val_auc: 0.8676 - val_loss: 0.1381
# Epoch 36/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6849 - auc: 0.8756 - loss: 0.1099 - val_accuracy: 0.5833 - val_auc: 0.8643 - val_loss: 0.1379
# Epoch 37/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6762 - auc: 0.8794 - loss: 0.1080 - val_accuracy: 0.6111 - val_auc: 0.8674 - val_loss: 0.1315
# Epoch 38/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6775 - auc: 0.8777 - loss: 0.1101 - val_accuracy: 0.6389 - val_auc: 0.8677 - val_loss: 0.1301
# Epoch 39/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6578 - auc: 0.8607 - loss: 0.1160 - val_accuracy: 0.6111 - val_auc: 0.8668 - val_loss: 0.1304
# Epoch 40/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6377 - auc: 0.8675 - loss: 0.1127 - val_accuracy: 0.6111 - val_auc: 0.8844 - val_loss: 0.1289
# Epoch 41/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6926 - auc: 0.8586 - loss: 0.1129 - val_accuracy: 0.5833 - val_auc: 0.8662 - val_loss: 0.1299
# Epoch 42/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7389 - auc: 0.8685 - loss: 0.1162 - val_accuracy: 0.6111 - val_auc: 0.8787 - val_loss: 0.1297
# Epoch 43/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6881 - auc: 0.8922 - loss: 0.1064 - val_accuracy: 0.6389 - val_auc: 0.8586 - val_loss: 0.1261
# Epoch 44/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7147 - auc: 0.8710 - loss: 0.1090 - val_accuracy: 0.6389 - val_auc: 0.8849 - val_loss: 0.1273
# Epoch 45/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7286 - auc: 0.8906 - loss: 0.1061 - val_accuracy: 0.6389 - val_auc: 0.8710 - val_loss: 0.1270
# Epoch 46/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7636 - auc: 0.8818 - loss: 0.1034 - val_accuracy: 0.6389 - val_auc: 0.8792 - val_loss: 0.1265
# Epoch 47/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7099 - auc: 0.8862 - loss: 0.1055 - val_accuracy: 0.6389 - val_auc: 0.8793 - val_loss: 0.1276
# Epoch 48/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7739 - auc: 0.8823 - loss: 0.1069 - val_accuracy: 0.6389 - val_auc: 0.8605 - val_loss: 0.1307
# Epoch 49/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6916 - auc: 0.8851 - loss: 0.1004 - val_accuracy: 0.6389 - val_auc: 0.8750 - val_loss: 0.1282
# Epoch 50/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7718 - auc: 0.8910 - loss: 0.1039 - val_accuracy: 0.6111 - val_auc: 0.8821 - val_loss: 0.1264
# Epoch 51/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6400 - auc: 0.8874 - loss: 0.1034 - val_accuracy: 0.5833 - val_auc: 0.8814 - val_loss: 0.1277
# Epoch 52/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6969 - auc: 0.8987 - loss: 0.0988 - val_accuracy: 0.6111 - val_auc: 0.8855 - val_loss: 0.1247
# Epoch 53/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7240 - auc: 0.8914 - loss: 0.1046 - val_accuracy: 0.6111 - val_auc: 0.8546 - val_loss: 0.1269
# Epoch 54/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6736 - auc: 0.8851 - loss: 0.0995 - val_accuracy: 0.6111 - val_auc: 0.8628 - val_loss: 0.1286
# Epoch 55/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7321 - auc: 0.8979 - loss: 0.0984 - val_accuracy: 0.6389 - val_auc: 0.8776 - val_loss: 0.1257
# Epoch 56/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6419 - auc: 0.8807 - loss: 0.1020 - val_accuracy: 0.6389 - val_auc: 0.8678 - val_loss: 0.1246
# Epoch 57/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7070 - auc: 0.8819 - loss: 0.1091 - val_accuracy: 0.6389 - val_auc: 0.8785 - val_loss: 0.1228
# Epoch 58/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6975 - auc: 0.8950 - loss: 0.0941 - val_accuracy: 0.6389 - val_auc: 0.8752 - val_loss: 0.1263
# Epoch 59/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7419 - auc: 0.8767 - loss: 0.1019 - val_accuracy: 0.6389 - val_auc: 0.8648 - val_loss: 0.1247
# Epoch 60/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7020 - auc: 0.8770 - loss: 0.1021 - val_accuracy: 0.6389 - val_auc: 0.8749 - val_loss: 0.1230
# Epoch 61/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7205 - auc: 0.8911 - loss: 0.1023 - val_accuracy: 0.6389 - val_auc: 0.8839 - val_loss: 0.1225
# Epoch 62/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7261 - auc: 0.8854 - loss: 0.1043 - val_accuracy: 0.6389 - val_auc: 0.8606 - val_loss: 0.1238
# Epoch 63/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7600 - auc: 0.8681 - loss: 0.1008 - val_accuracy: 0.6389 - val_auc: 0.8722 - val_loss: 0.1234
# Epoch 64/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7041 - auc: 0.8901 - loss: 0.0944 - val_accuracy: 0.6389 - val_auc: 0.8715 - val_loss: 0.1230
# Epoch 65/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7079 - auc: 0.8845 - loss: 0.0978 - val_accuracy: 0.6111 - val_auc: 0.8750 - val_loss: 0.1225
# Epoch 66/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7037 - auc: 0.8839 - loss: 0.1050 - val_accuracy: 0.6389 - val_auc: 0.8652 - val_loss: 0.1247
# Epoch 67/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7193 - auc: 0.8779 - loss: 0.0981 - val_accuracy: 0.6389 - val_auc: 0.8636 - val_loss: 0.1251
# Epoch 68/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7117 - auc: 0.8881 - loss: 0.0910 - val_accuracy: 0.6389 - val_auc: 0.8613 - val_loss: 0.1269
# Epoch 69/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7180 - auc: 0.8783 - loss: 0.0959 - val_accuracy: 0.6389 - val_auc: 0.8833 - val_loss: 0.1236
# Epoch 70/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7073 - auc: 0.8853 - loss: 0.1000 - val_accuracy: 0.6389 - val_auc: 0.8758 - val_loss: 0.1248
# Epoch 71/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6989 - auc: 0.8869 - loss: 0.0991 - val_accuracy: 0.6389 - val_auc: 0.8649 - val_loss: 0.1261
# Epoch 72/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7280 - auc: 0.8757 - loss: 0.0938 - val_accuracy: 0.6389 - val_auc: 0.8842 - val_loss: 0.1265
# Epoch 73/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7491 - auc: 0.9022 - loss: 0.0914 - val_accuracy: 0.6667 - val_auc: 0.8734 - val_loss: 0.1259
# Epoch 74/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7539 - auc: 0.8822 - loss: 0.0950 - val_accuracy: 0.6389 - val_auc: 0.8655 - val_loss: 0.1233
# Epoch 75/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7390 - auc: 0.8899 - loss: 0.0885 - val_accuracy: 0.6111 - val_auc: 0.8661 - val_loss: 0.1242
# Epoch 76/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7190 - auc: 0.9012 - loss: 0.0900 - val_accuracy: 0.6111 - val_auc: 0.8674 - val_loss: 0.1231
# Epoch 77/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6930 - auc: 0.8826 - loss: 0.0942 - val_accuracy: 0.6389 - val_auc: 0.8704 - val_loss: 0.1246
# Epoch 78/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6733 - auc: 0.8974 - loss: 0.0919 - val_accuracy: 0.6389 - val_auc: 0.8922 - val_loss: 0.1233
# Epoch 79/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7390 - auc: 0.8937 - loss: 0.0970 - val_accuracy: 0.6667 - val_auc: 0.8784 - val_loss: 0.1213
# Epoch 80/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7866 - auc: 0.8884 - loss: 0.0873 - val_accuracy: 0.6389 - val_auc: 0.8766 - val_loss: 0.1229
# Epoch 81/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7315 - auc: 0.8943 - loss: 0.0877 - val_accuracy: 0.6667 - val_auc: 0.8779 - val_loss: 0.1198
# Epoch 82/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7578 - auc: 0.8896 - loss: 0.0969 - val_accuracy: 0.6667 - val_auc: 0.8823 - val_loss: 0.1219
# Epoch 83/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7263 - auc: 0.8931 - loss: 0.0989 - val_accuracy: 0.6667 - val_auc: 0.8747 - val_loss: 0.1247
# Epoch 84/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6850 - auc: 0.8785 - loss: 0.0963 - val_accuracy: 0.6667 - val_auc: 0.8675 - val_loss: 0.1249
# Epoch 85/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7185 - auc: 0.8845 - loss: 0.0944 - val_accuracy: 0.6944 - val_auc: 0.8755 - val_loss: 0.1235
# Epoch 86/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7558 - auc: 0.8831 - loss: 0.0959 - val_accuracy: 0.6389 - val_auc: 0.8851 - val_loss: 0.1199
# Epoch 87/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7231 - auc: 0.8941 - loss: 0.0952 - val_accuracy: 0.6389 - val_auc: 0.8661 - val_loss: 0.1220
# Epoch 88/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7561 - auc: 0.8846 - loss: 0.0902 - val_accuracy: 0.6389 - val_auc: 0.8832 - val_loss: 0.1247
# Epoch 89/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7626 - auc: 0.8961 - loss: 0.0911 - val_accuracy: 0.6389 - val_auc: 0.8829 - val_loss: 0.1219
# Epoch 90/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7192 - auc: 0.8815 - loss: 0.0899 - val_accuracy: 0.6389 - val_auc: 0.8561 - val_loss: 0.1213
# Epoch 91/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6667 - auc: 0.8798 - loss: 0.0915 - val_accuracy: 0.6389 - val_auc: 0.8761 - val_loss: 0.1229
# Epoch 92/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7060 - auc: 0.8813 - loss: 0.0962 - val_accuracy: 0.6389 - val_auc: 0.8726 - val_loss: 0.1214
# Epoch 93/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7415 - auc: 0.8887 - loss: 0.0916 - val_accuracy: 0.6667 - val_auc: 0.8625 - val_loss: 0.1206
# Epoch 94/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7847 - auc: 0.8759 - loss: 0.0889 - val_accuracy: 0.6389 - val_auc: 0.8721 - val_loss: 0.1201
# Epoch 95/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7471 - auc: 0.8781 - loss: 0.0911 - val_accuracy: 0.6111 - val_auc: 0.8667 - val_loss: 0.1199
# Epoch 96/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7070 - auc: 0.8859 - loss: 0.0936 - val_accuracy: 0.6389 - val_auc: 0.8688 - val_loss: 0.1205
# Epoch 97/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6972 - auc: 0.8823 - loss: 0.0919 - val_accuracy: 0.6389 - val_auc: 0.8765 - val_loss: 0.1208
# Epoch 98/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7386 - auc: 0.8778 - loss: 0.0975 - val_accuracy: 0.6389 - val_auc: 0.8763 - val_loss: 0.1201
# Epoch 99/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6827 - auc: 0.8872 - loss: 0.0890 - val_accuracy: 0.6389 - val_auc: 0.8814 - val_loss: 0.1199
# Epoch 100/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7522 - auc: 0.8897 - loss: 0.0942 - val_accuracy: 0.6111 - val_auc: 0.8863 - val_loss: 0.1201
# Epoch 101/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7183 - auc: 0.8788 - loss: 0.0971 - val_accuracy: 0.6111 - val_auc: 0.8613 - val_loss: 0.1241
# Epoch 102/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7118 - auc: 0.8771 - loss: 0.0892 - val_accuracy: 0.6111 - val_auc: 0.8562 - val_loss: 0.1238
# Epoch 103/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7865 - auc: 0.8776 - loss: 0.0884 - val_accuracy: 0.6111 - val_auc: 0.8828 - val_loss: 0.1210
# Epoch 104/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7399 - auc: 0.8975 - loss: 0.0872 - val_accuracy: 0.6111 - val_auc: 0.8799 - val_loss: 0.1207
# Epoch 105/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7465 - auc: 0.8874 - loss: 0.0874 - val_accuracy: 0.6389 - val_auc: 0.8614 - val_loss: 0.1199
# Epoch 106/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7632 - auc: 0.8838 - loss: 0.0892 - val_accuracy: 0.6389 - val_auc: 0.8809 - val_loss: 0.1204
# Epoch 107/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7365 - auc: 0.8963 - loss: 0.0856 - val_accuracy: 0.6389 - val_auc: 0.8670 - val_loss: 0.1217
# Epoch 108/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7315 - auc: 0.8716 - loss: 0.0923 - val_accuracy: 0.6667 - val_auc: 0.8802 - val_loss: 0.1207
# Epoch 109/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7419 - auc: 0.8871 - loss: 0.0922 - val_accuracy: 0.6667 - val_auc: 0.8824 - val_loss: 0.1219
# Epoch 110/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8184 - auc: 0.8834 - loss: 0.0922 - val_accuracy: 0.6389 - val_auc: 0.8607 - val_loss: 0.1211
# Epoch 111/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6879 - auc: 0.8777 - loss: 0.0931 - val_accuracy: 0.6389 - val_auc: 0.8641 - val_loss: 0.1214
# Epoch 112/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7454 - auc: 0.8836 - loss: 0.0877 - val_accuracy: 0.6389 - val_auc: 0.8754 - val_loss: 0.1221
# Epoch 113/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7475 - auc: 0.8923 - loss: 0.0903 - val_accuracy: 0.6389 - val_auc: 0.8754 - val_loss: 0.1240
# Epoch 114/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7688 - auc: 0.8818 - loss: 0.0869 - val_accuracy: 0.5833 - val_auc: 0.8728 - val_loss: 0.1214
# Epoch 115/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7891 - auc: 0.8800 - loss: 0.0889 - val_accuracy: 0.5833 - val_auc: 0.8653 - val_loss: 0.1217
# Epoch 116/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7130 - auc: 0.8890 - loss: 0.0841 - val_accuracy: 0.6111 - val_auc: 0.8835 - val_loss: 0.1238
# Epoch 117/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7143 - auc: 0.8974 - loss: 0.0836 - val_accuracy: 0.6111 - val_auc: 0.8849 - val_loss: 0.1237
# Epoch 118/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7193 - auc: 0.8823 - loss: 0.0869 - val_accuracy: 0.5833 - val_auc: 0.8735 - val_loss: 0.1238
# Epoch 119/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7308 - auc: 0.8726 - loss: 0.0837 - val_accuracy: 0.5833 - val_auc: 0.8750 - val_loss: 0.1225
# Epoch 120/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7750 - auc: 0.8949 - loss: 0.0807 - val_accuracy: 0.5833 - val_auc: 0.8832 - val_loss: 0.1215
# Epoch 121/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7367 - auc: 0.8990 - loss: 0.0846 - val_accuracy: 0.5833 - val_auc: 0.8805 - val_loss: 0.1263
# Epoch 122/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6978 - auc: 0.8876 - loss: 0.0868 - val_accuracy: 0.5833 - val_auc: 0.8641 - val_loss: 0.1321
# Epoch 123/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7384 - auc: 0.8777 - loss: 0.0898 - val_accuracy: 0.6111 - val_auc: 0.8737 - val_loss: 0.1290
# Epoch 124/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8103 - auc: 0.8914 - loss: 0.0837 - val_accuracy: 0.5833 - val_auc: 0.8794 - val_loss: 0.1265
# Epoch 125/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7228 - auc: 0.8809 - loss: 0.0934 - val_accuracy: 0.5833 - val_auc: 0.8763 - val_loss: 0.1245
# Epoch 126/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6617 - auc: 0.8796 - loss: 0.0928 - val_accuracy: 0.5833 - val_auc: 0.8678 - val_loss: 0.1236
# Epoch 127/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6923 - auc: 0.8766 - loss: 0.0843 - val_accuracy: 0.5833 - val_auc: 0.8670 - val_loss: 0.1250
# Epoch 128/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7852 - auc: 0.8828 - loss: 0.0815 - val_accuracy: 0.6111 - val_auc: 0.8783 - val_loss: 0.1229
# Epoch 129/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7885 - auc: 0.8967 - loss: 0.0818 - val_accuracy: 0.6389 - val_auc: 0.8783 - val_loss: 0.1240
# Epoch 130/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7418 - auc: 0.8847 - loss: 0.0799 - val_accuracy: 0.6389 - val_auc: 0.8912 - val_loss: 0.1230
# Epoch 131/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7433 - auc: 0.8927 - loss: 0.0786 - val_accuracy: 0.6111 - val_auc: 0.8713 - val_loss: 0.1246
# Epoch 132/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7935 - auc: 0.8881 - loss: 0.0844 - val_accuracy: 0.5833 - val_auc: 0.8772 - val_loss: 0.1236
# Epoch 133/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7335 - auc: 0.8835 - loss: 0.0954 - val_accuracy: 0.6111 - val_auc: 0.8914 - val_loss: 0.1227
# Epoch 134/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7559 - auc: 0.8984 - loss: 0.0790 - val_accuracy: 0.6111 - val_auc: 0.8863 - val_loss: 0.1227
# Epoch 135/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7444 - auc: 0.8943 - loss: 0.0797 - val_accuracy: 0.6111 - val_auc: 0.8734 - val_loss: 0.1212
# Epoch 136/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7736 - auc: 0.8901 - loss: 0.0780 - val_accuracy: 0.6111 - val_auc: 0.8894 - val_loss: 0.1198
# Epoch 137/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7198 - auc: 0.8864 - loss: 0.0844 - val_accuracy: 0.5833 - val_auc: 0.8923 - val_loss: 0.1207
# Epoch 138/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7474 - auc: 0.8973 - loss: 0.0766 - val_accuracy: 0.5833 - val_auc: 0.8763 - val_loss: 0.1202
# Epoch 139/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7240 - auc: 0.8797 - loss: 0.0924 - val_accuracy: 0.6389 - val_auc: 0.8688 - val_loss: 0.1223
# Epoch 140/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7980 - auc: 0.8959 - loss: 0.0780 - val_accuracy: 0.6389 - val_auc: 0.8973 - val_loss: 0.1232
# Epoch 141/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7079 - auc: 0.9039 - loss: 0.0782 - val_accuracy: 0.6667 - val_auc: 0.8776 - val_loss: 0.1224
# Epoch 142/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7535 - auc: 0.8905 - loss: 0.0781 - val_accuracy: 0.6111 - val_auc: 0.8800 - val_loss: 0.1234
# Epoch 143/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7666 - auc: 0.8842 - loss: 0.0796 - val_accuracy: 0.6111 - val_auc: 0.8877 - val_loss: 0.1218
# Epoch 144/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7468 - auc: 0.8955 - loss: 0.0749 - val_accuracy: 0.6389 - val_auc: 0.8773 - val_loss: 0.1196
# Epoch 145/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7303 - auc: 0.9028 - loss: 0.0754 - val_accuracy: 0.6389 - val_auc: 0.8735 - val_loss: 0.1202
# Epoch 146/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7593 - auc: 0.8952 - loss: 0.0805 - val_accuracy: 0.6389 - val_auc: 0.8877 - val_loss: 0.1220
# Epoch 147/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7488 - auc: 0.9040 - loss: 0.0766 - val_accuracy: 0.6389 - val_auc: 0.8848 - val_loss: 0.1211
# Epoch 148/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7611 - auc: 0.8961 - loss: 0.0763 - val_accuracy: 0.6389 - val_auc: 0.8769 - val_loss: 0.1218
# Epoch 149/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7428 - auc: 0.8842 - loss: 0.0838 - val_accuracy: 0.6389 - val_auc: 0.8731 - val_loss: 0.1228
# Epoch 150/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7127 - auc: 0.8892 - loss: 0.0798 - val_accuracy: 0.6111 - val_auc: 0.8684 - val_loss: 0.1229
# Epoch 151/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7933 - auc: 0.8879 - loss: 0.0771 - val_accuracy: 0.6389 - val_auc: 0.8781 - val_loss: 0.1221
# Epoch 152/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7854 - auc: 0.8886 - loss: 0.0814 - val_accuracy: 0.6111 - val_auc: 0.8788 - val_loss: 0.1239
# Epoch 153/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6787 - auc: 0.8881 - loss: 0.0828 - val_accuracy: 0.6111 - val_auc: 0.8870 - val_loss: 0.1249
# Epoch 154/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7548 - auc: 0.8810 - loss: 0.0879 - val_accuracy: 0.6944 - val_auc: 0.8829 - val_loss: 0.1232
# Epoch 155/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7601 - auc: 0.8811 - loss: 0.0879 - val_accuracy: 0.6667 - val_auc: 0.8698 - val_loss: 0.1247
# Epoch 156/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7564 - auc: 0.8770 - loss: 0.0863 - val_accuracy: 0.6389 - val_auc: 0.8760 - val_loss: 0.1252
# Epoch 157/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7604 - auc: 0.8970 - loss: 0.0820 - val_accuracy: 0.5556 - val_auc: 0.8580 - val_loss: 0.1266
# Epoch 158/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7488 - auc: 0.8818 - loss: 0.0792 - val_accuracy: 0.5833 - val_auc: 0.8587 - val_loss: 0.1226
# Epoch 159/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7444 - auc: 0.8882 - loss: 0.0797 - val_accuracy: 0.5556 - val_auc: 0.8777 - val_loss: 0.1204
# Epoch 160/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7711 - auc: 0.8924 - loss: 0.0769 - val_accuracy: 0.5833 - val_auc: 0.8851 - val_loss: 0.1199
# Epoch 161/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7746 - auc: 0.8860 - loss: 0.0784 - val_accuracy: 0.5833 - val_auc: 0.8834 - val_loss: 0.1217
# Epoch 162/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7606 - auc: 0.8978 - loss: 0.0800 - val_accuracy: 0.6111 - val_auc: 0.8772 - val_loss: 0.1178
# Epoch 163/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7297 - auc: 0.8985 - loss: 0.0737 - val_accuracy: 0.5556 - val_auc: 0.8798 - val_loss: 0.1170
# Epoch 164/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7468 - auc: 0.8963 - loss: 0.0742 - val_accuracy: 0.5833 - val_auc: 0.8824 - val_loss: 0.1200
# Epoch 165/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7516 - auc: 0.8956 - loss: 0.0813 - val_accuracy: 0.5833 - val_auc: 0.8718 - val_loss: 0.1312
# Epoch 166/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7727 - auc: 0.8931 - loss: 0.0837 - val_accuracy: 0.5833 - val_auc: 0.8618 - val_loss: 0.1407
# Epoch 167/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7960 - auc: 0.8905 - loss: 0.0834 - val_accuracy: 0.5833 - val_auc: 0.8602 - val_loss: 0.1397
# Epoch 168/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7378 - auc: 0.8874 - loss: 0.0871 - val_accuracy: 0.5833 - val_auc: 0.8751 - val_loss: 0.1437
# Epoch 169/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7763 - auc: 0.8964 - loss: 0.0825 - val_accuracy: 0.5833 - val_auc: 0.8756 - val_loss: 0.1395
# Epoch 170/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8021 - auc: 0.8938 - loss: 0.0813 - val_accuracy: 0.5833 - val_auc: 0.8578 - val_loss: 0.1340
# Epoch 171/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7481 - auc: 0.8840 - loss: 0.0799 - val_accuracy: 0.5833 - val_auc: 0.8722 - val_loss: 0.1285
# Epoch 172/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7666 - auc: 0.9005 - loss: 0.0780 - val_accuracy: 0.6111 - val_auc: 0.8818 - val_loss: 0.1258
# Epoch 173/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7099 - auc: 0.8965 - loss: 0.0843 - val_accuracy: 0.6111 - val_auc: 0.8775 - val_loss: 0.1237
# Epoch 174/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6929 - auc: 0.8937 - loss: 0.0784 - val_accuracy: 0.6111 - val_auc: 0.8741 - val_loss: 0.1220
# Epoch 175/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7792 - auc: 0.8920 - loss: 0.0789 - val_accuracy: 0.5556 - val_auc: 0.8762 - val_loss: 0.1233
# Epoch 176/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7390 - auc: 0.8869 - loss: 0.0757 - val_accuracy: 0.5556 - val_auc: 0.8735 - val_loss: 0.1285
# Epoch 177/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6771 - auc: 0.8852 - loss: 0.0776 - val_accuracy: 0.5556 - val_auc: 0.8784 - val_loss: 0.1295
# Epoch 178/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7708 - auc: 0.9012 - loss: 0.0777 - val_accuracy: 0.5556 - val_auc: 0.8868 - val_loss: 0.1288
# Epoch 179/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8319 - auc: 0.9030 - loss: 0.0709 - val_accuracy: 0.5278 - val_auc: 0.8789 - val_loss: 0.1253
# Epoch 180/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8147 - auc: 0.8936 - loss: 0.0738 - val_accuracy: 0.5556 - val_auc: 0.8770 - val_loss: 0.1226
# Epoch 181/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7659 - auc: 0.8922 - loss: 0.0754 - val_accuracy: 0.5556 - val_auc: 0.8750 - val_loss: 0.1225
# Epoch 182/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7410 - auc: 0.8906 - loss: 0.0810 - val_accuracy: 0.6111 - val_auc: 0.8875 - val_loss: 0.1216
# Epoch 183/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7799 - auc: 0.8954 - loss: 0.0776 - val_accuracy: 0.6111 - val_auc: 0.8775 - val_loss: 0.1223
# Epoch 184/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8345 - auc: 0.9002 - loss: 0.0728 - val_accuracy: 0.6111 - val_auc: 0.8704 - val_loss: 0.1206
# Epoch 185/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6801 - auc: 0.8883 - loss: 0.0829 - val_accuracy: 0.5833 - val_auc: 0.8743 - val_loss: 0.1203
# Epoch 186/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7662 - auc: 0.8921 - loss: 0.0759 - val_accuracy: 0.6111 - val_auc: 0.8782 - val_loss: 0.1203
# Epoch 187/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7432 - auc: 0.8993 - loss: 0.0744 - val_accuracy: 0.5556 - val_auc: 0.8789 - val_loss: 0.1188
# Epoch 188/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7915 - auc: 0.8938 - loss: 0.0697 - val_accuracy: 0.5556 - val_auc: 0.8857 - val_loss: 0.1193
# Epoch 189/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7037 - auc: 0.8965 - loss: 0.0721 - val_accuracy: 0.5833 - val_auc: 0.8822 - val_loss: 0.1194
# Epoch 190/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7846 - auc: 0.8825 - loss: 0.0781 - val_accuracy: 0.6389 - val_auc: 0.8829 - val_loss: 0.1189
# Epoch 191/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7517 - auc: 0.8885 - loss: 0.0779 - val_accuracy: 0.6111 - val_auc: 0.8826 - val_loss: 0.1177
# Epoch 192/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7695 - auc: 0.8939 - loss: 0.0699 - val_accuracy: 0.6111 - val_auc: 0.8913 - val_loss: 0.1184
# Epoch 193/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7360 - auc: 0.9021 - loss: 0.0718 - val_accuracy: 0.6389 - val_auc: 0.8907 - val_loss: 0.1181
# Epoch 194/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7652 - auc: 0.9011 - loss: 0.0743 - val_accuracy: 0.6111 - val_auc: 0.8854 - val_loss: 0.1178
# Epoch 195/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8060 - auc: 0.8946 - loss: 0.0735 - val_accuracy: 0.6389 - val_auc: 0.8855 - val_loss: 0.1183
# Epoch 196/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7721 - auc: 0.8985 - loss: 0.0739 - val_accuracy: 0.6389 - val_auc: 0.8799 - val_loss: 0.1167
# Epoch 197/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7595 - auc: 0.8845 - loss: 0.0712 - val_accuracy: 0.6389 - val_auc: 0.8806 - val_loss: 0.1154
# Epoch 198/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6842 - auc: 0.8948 - loss: 0.0720 - val_accuracy: 0.6111 - val_auc: 0.8848 - val_loss: 0.1172
# Epoch 199/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7279 - auc: 0.8923 - loss: 0.0808 - val_accuracy: 0.6111 - val_auc: 0.8715 - val_loss: 0.1165
# Epoch 200/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7967 - auc: 0.8866 - loss: 0.0802 - val_accuracy: 0.5833 - val_auc: 0.8775 - val_loss: 0.1175
# Epoch 201/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7603 - auc: 0.9003 - loss: 0.0722 - val_accuracy: 0.5833 - val_auc: 0.8760 - val_loss: 0.1201
# Epoch 202/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7626 - auc: 0.8902 - loss: 0.0740 - val_accuracy: 0.5833 - val_auc: 0.8746 - val_loss: 0.1203
# Epoch 203/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7522 - auc: 0.8988 - loss: 0.0785 - val_accuracy: 0.5833 - val_auc: 0.8855 - val_loss: 0.1197
# Epoch 204/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7441 - auc: 0.8986 - loss: 0.0705 - val_accuracy: 0.6111 - val_auc: 0.8920 - val_loss: 0.1194
# Epoch 205/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7672 - auc: 0.8918 - loss: 0.0819 - val_accuracy: 0.6389 - val_auc: 0.8850 - val_loss: 0.1181
# Epoch 206/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7127 - auc: 0.8881 - loss: 0.0793 - val_accuracy: 0.6389 - val_auc: 0.8764 - val_loss: 0.1192
# Epoch 207/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7717 - auc: 0.8883 - loss: 0.0709 - val_accuracy: 0.6389 - val_auc: 0.8810 - val_loss: 0.1207
# Epoch 208/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7889 - auc: 0.8938 - loss: 0.0701 - val_accuracy: 0.6667 - val_auc: 0.8813 - val_loss: 0.1202
# Epoch 209/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7962 - auc: 0.9035 - loss: 0.0673 - val_accuracy: 0.6667 - val_auc: 0.8788 - val_loss: 0.1177
# Epoch 210/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7397 - auc: 0.8996 - loss: 0.0755 - val_accuracy: 0.6111 - val_auc: 0.8846 - val_loss: 0.1173
# Epoch 211/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8082 - auc: 0.8934 - loss: 0.0713 - val_accuracy: 0.6111 - val_auc: 0.8903 - val_loss: 0.1181
# Epoch 212/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7902 - auc: 0.9043 - loss: 0.0681 - val_accuracy: 0.6111 - val_auc: 0.8766 - val_loss: 0.1187
# Epoch 213/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7831 - auc: 0.8945 - loss: 0.0678 - val_accuracy: 0.6111 - val_auc: 0.8672 - val_loss: 0.1195
# Epoch 214/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7337 - auc: 0.8997 - loss: 0.0707 - val_accuracy: 0.6111 - val_auc: 0.8734 - val_loss: 0.1186
# Epoch 215/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7390 - auc: 0.8884 - loss: 0.0769 - val_accuracy: 0.6111 - val_auc: 0.8700 - val_loss: 0.1180
# Epoch 216/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7611 - auc: 0.8730 - loss: 0.0744 - val_accuracy: 0.6111 - val_auc: 0.8826 - val_loss: 0.1184
# Epoch 217/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7737 - auc: 0.8914 - loss: 0.0692 - val_accuracy: 0.5833 - val_auc: 0.8824 - val_loss: 0.1269
# Epoch 218/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8015 - auc: 0.8910 - loss: 0.0763 - val_accuracy: 0.5833 - val_auc: 0.8752 - val_loss: 0.1291
# Epoch 219/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8008 - auc: 0.8842 - loss: 0.0704 - val_accuracy: 0.5833 - val_auc: 0.8802 - val_loss: 0.1260
# Epoch 220/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7703 - auc: 0.8954 - loss: 0.0707 - val_accuracy: 0.6111 - val_auc: 0.8752 - val_loss: 0.1239
# Epoch 221/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7529 - auc: 0.8873 - loss: 0.0815 - val_accuracy: 0.6389 - val_auc: 0.8688 - val_loss: 0.1236
# Epoch 222/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7552 - auc: 0.8942 - loss: 0.0689 - val_accuracy: 0.6111 - val_auc: 0.8722 - val_loss: 0.1233
# Epoch 223/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7085 - auc: 0.8861 - loss: 0.0750 - val_accuracy: 0.6111 - val_auc: 0.8815 - val_loss: 0.1202
# Epoch 224/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7339 - auc: 0.8941 - loss: 0.0720 - val_accuracy: 0.6111 - val_auc: 0.8781 - val_loss: 0.1200
# Epoch 225/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7956 - auc: 0.9003 - loss: 0.0673 - val_accuracy: 0.6111 - val_auc: 0.8803 - val_loss: 0.1209
# Epoch 226/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7031 - auc: 0.9024 - loss: 0.0716 - val_accuracy: 0.6111 - val_auc: 0.8801 - val_loss: 0.1212
# Epoch 227/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7950 - auc: 0.9032 - loss: 0.0668 - val_accuracy: 0.6111 - val_auc: 0.8754 - val_loss: 0.1208
# Epoch 228/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8038 - auc: 0.8940 - loss: 0.0670 - val_accuracy: 0.6111 - val_auc: 0.8780 - val_loss: 0.1233
# Epoch 229/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7512 - auc: 0.8881 - loss: 0.0763 - val_accuracy: 0.6111 - val_auc: 0.8803 - val_loss: 0.1216
# Epoch 230/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7992 - auc: 0.9068 - loss: 0.0650 - val_accuracy: 0.6111 - val_auc: 0.8801 - val_loss: 0.1204
# Epoch 231/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7844 - auc: 0.9023 - loss: 0.0715 - val_accuracy: 0.6111 - val_auc: 0.8745 - val_loss: 0.1193
# Epoch 232/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7755 - auc: 0.9064 - loss: 0.0663 - val_accuracy: 0.6111 - val_auc: 0.8688 - val_loss: 0.1204
# Epoch 233/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7808 - auc: 0.9037 - loss: 0.0703 - val_accuracy: 0.6111 - val_auc: 0.8716 - val_loss: 0.1209
# Epoch 234/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7558 - auc: 0.8948 - loss: 0.0698 - val_accuracy: 0.6111 - val_auc: 0.8769 - val_loss: 0.1183
# Epoch 235/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7499 - auc: 0.9005 - loss: 0.0615 - val_accuracy: 0.6111 - val_auc: 0.8768 - val_loss: 0.1182
# Epoch 236/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8280 - auc: 0.8993 - loss: 0.0646 - val_accuracy: 0.6389 - val_auc: 0.8778 - val_loss: 0.1165
# Epoch 237/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7815 - auc: 0.8939 - loss: 0.0641 - val_accuracy: 0.6111 - val_auc: 0.8928 - val_loss: 0.1146
# Epoch 238/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7824 - auc: 0.8974 - loss: 0.0661 - val_accuracy: 0.6389 - val_auc: 0.8894 - val_loss: 0.1159
# Epoch 239/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8001 - auc: 0.8961 - loss: 0.0634 - val_accuracy: 0.6111 - val_auc: 0.8797 - val_loss: 0.1170
# Epoch 240/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8170 - auc: 0.9076 - loss: 0.0656 - val_accuracy: 0.6111 - val_auc: 0.8777 - val_loss: 0.1172
# Epoch 241/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7782 - auc: 0.8994 - loss: 0.0665 - val_accuracy: 0.5833 - val_auc: 0.8820 - val_loss: 0.1158
# Epoch 242/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7804 - auc: 0.8961 - loss: 0.0688 - val_accuracy: 0.5833 - val_auc: 0.8809 - val_loss: 0.1171
# Epoch 243/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8071 - auc: 0.8998 - loss: 0.0658 - val_accuracy: 0.5833 - val_auc: 0.8827 - val_loss: 0.1192
# Epoch 244/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7768 - auc: 0.9058 - loss: 0.0624 - val_accuracy: 0.5833 - val_auc: 0.8836 - val_loss: 0.1203
# Epoch 245/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8074 - auc: 0.8998 - loss: 0.0660 - val_accuracy: 0.5833 - val_auc: 0.8868 - val_loss: 0.1222
# Epoch 246/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7491 - auc: 0.8924 - loss: 0.0829 - val_accuracy: 0.5833 - val_auc: 0.8690 - val_loss: 0.1221
# Epoch 247/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8478 - auc: 0.8857 - loss: 0.0637 - val_accuracy: 0.5833 - val_auc: 0.8797 - val_loss: 0.1199
# Epoch 248/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7878 - auc: 0.8967 - loss: 0.0677 - val_accuracy: 0.5833 - val_auc: 0.8684 - val_loss: 0.1209
# Epoch 249/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7930 - auc: 0.8848 - loss: 0.0700 - val_accuracy: 0.5833 - val_auc: 0.8725 - val_loss: 0.1224
# Epoch 250/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7937 - auc: 0.8926 - loss: 0.0682 - val_accuracy: 0.5833 - val_auc: 0.8772 - val_loss: 0.1217
# Epoch 251/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7817 - auc: 0.8939 - loss: 0.0668 - val_accuracy: 0.6111 - val_auc: 0.8816 - val_loss: 0.1200
# Epoch 252/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8225 - auc: 0.9036 - loss: 0.0632 - val_accuracy: 0.6111 - val_auc: 0.8787 - val_loss: 0.1204
# Epoch 253/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7052 - auc: 0.8937 - loss: 0.0684 - val_accuracy: 0.6111 - val_auc: 0.8804 - val_loss: 0.1194
# Epoch 254/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7454 - auc: 0.8834 - loss: 0.0720 - val_accuracy: 0.6111 - val_auc: 0.8794 - val_loss: 0.1208
# Epoch 255/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7827 - auc: 0.8931 - loss: 0.0673 - val_accuracy: 0.5833 - val_auc: 0.8782 - val_loss: 0.1207
# Epoch 256/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8190 - auc: 0.8922 - loss: 0.0662 - val_accuracy: 0.5833 - val_auc: 0.8842 - val_loss: 0.1202
# Epoch 257/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7853 - auc: 0.9039 - loss: 0.0636 - val_accuracy: 0.5833 - val_auc: 0.8810 - val_loss: 0.1197
# Epoch 258/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7101 - auc: 0.8961 - loss: 0.0672 - val_accuracy: 0.5833 - val_auc: 0.8805 - val_loss: 0.1186
# Epoch 259/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8058 - auc: 0.9032 - loss: 0.0634 - val_accuracy: 0.5833 - val_auc: 0.8864 - val_loss: 0.1166
# Epoch 260/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7218 - auc: 0.8995 - loss: 0.0624 - val_accuracy: 0.6111 - val_auc: 0.8844 - val_loss: 0.1147
# Epoch 261/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7510 - auc: 0.8863 - loss: 0.0710 - val_accuracy: 0.6111 - val_auc: 0.8849 - val_loss: 0.1178
# Epoch 262/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7611 - auc: 0.8946 - loss: 0.0662 - val_accuracy: 0.6389 - val_auc: 0.8905 - val_loss: 0.1225
# Epoch 263/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7391 - auc: 0.8995 - loss: 0.0693 - val_accuracy: 0.6111 - val_auc: 0.8815 - val_loss: 0.1221
# Epoch 264/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8288 - auc: 0.8937 - loss: 0.0707 - val_accuracy: 0.5833 - val_auc: 0.8798 - val_loss: 0.1225
# Epoch 265/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7685 - auc: 0.9073 - loss: 0.0688 - val_accuracy: 0.6111 - val_auc: 0.8820 - val_loss: 0.1244
# Epoch 266/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7820 - auc: 0.8885 - loss: 0.0713 - val_accuracy: 0.5833 - val_auc: 0.8865 - val_loss: 0.1247
# Epoch 267/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7454 - auc: 0.8960 - loss: 0.0667 - val_accuracy: 0.5833 - val_auc: 0.8839 - val_loss: 0.1240
# Epoch 268/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7677 - auc: 0.8991 - loss: 0.0660 - val_accuracy: 0.5833 - val_auc: 0.8806 - val_loss: 0.1254
# Epoch 269/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7763 - auc: 0.8871 - loss: 0.0659 - val_accuracy: 0.5833 - val_auc: 0.8827 - val_loss: 0.1264
# Epoch 270/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7391 - auc: 0.8882 - loss: 0.0713 - val_accuracy: 0.5833 - val_auc: 0.8774 - val_loss: 0.1240
# Epoch 271/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.7648 - auc: 0.8903 - loss: 0.0661 - val_accuracy: 0.5833 - val_auc: 0.8754 - val_loss: 0.1217
# Epoch 272/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7888 - auc: 0.8964 - loss: 0.0662 - val_accuracy: 0.5833 - val_auc: 0.8833 - val_loss: 0.1205
# Epoch 273/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8184 - auc: 0.9011 - loss: 0.0678 - val_accuracy: 0.5833 - val_auc: 0.8937 - val_loss: 0.1193
# Epoch 274/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7658 - auc: 0.9097 - loss: 0.0607 - val_accuracy: 0.5833 - val_auc: 0.8788 - val_loss: 0.1186
# Epoch 275/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7849 - auc: 0.8953 - loss: 0.0666 - val_accuracy: 0.5833 - val_auc: 0.8848 - val_loss: 0.1209
# Epoch 276/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7121 - auc: 0.8916 - loss: 0.0772 - val_accuracy: 0.5833 - val_auc: 0.8828 - val_loss: 0.1215
# Epoch 277/2000
# ...
# Epoch 1909/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8320 - auc: 0.9067 - loss: 0.0357 - val_accuracy: 0.6111 - val_auc: 0.8775 - val_loss: 0.1225
# Epoch 1910/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8286 - auc: 0.9052 - loss: 0.0470 - val_accuracy: 0.6111 - val_auc: 0.8743 - val_loss: 0.1221
# Epoch 1911/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8293 - auc: 0.9124 - loss: 0.0330 - val_accuracy: 0.6111 - val_auc: 0.8707 - val_loss: 0.1209
# Epoch 1912/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8109 - auc: 0.9155 - loss: 0.0344 - val_accuracy: 0.6111 - val_auc: 0.8723 - val_loss: 0.1207
# Epoch 1913/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7711 - auc: 0.9087 - loss: 0.0378 - val_accuracy: 0.6111 - val_auc: 0.8733 - val_loss: 0.1216
# Epoch 1914/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7659 - auc: 0.9147 - loss: 0.0364 - val_accuracy: 0.5833 - val_auc: 0.8740 - val_loss: 0.1225
# Epoch 1915/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8600 - auc: 0.9063 - loss: 0.0420 - val_accuracy: 0.5833 - val_auc: 0.8780 - val_loss: 0.1234
# Epoch 1916/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7769 - auc: 0.9101 - loss: 0.0417 - val_accuracy: 0.5833 - val_auc: 0.8777 - val_loss: 0.1237
# Epoch 1917/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7917 - auc: 0.9138 - loss: 0.0408 - val_accuracy: 0.5833 - val_auc: 0.8800 - val_loss: 0.1240
# Epoch 1918/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8429 - auc: 0.9153 - loss: 0.0384 - val_accuracy: 0.5833 - val_auc: 0.8787 - val_loss: 0.1230
# Epoch 1919/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8339 - auc: 0.9026 - loss: 0.0466 - val_accuracy: 0.5833 - val_auc: 0.8743 - val_loss: 0.1205
# Epoch 1920/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7580 - auc: 0.9104 - loss: 0.0407 - val_accuracy: 0.6111 - val_auc: 0.8648 - val_loss: 0.1198
# Epoch 1921/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8076 - auc: 0.8895 - loss: 0.0423 - val_accuracy: 0.6111 - val_auc: 0.8654 - val_loss: 0.1185
# Epoch 1922/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7821 - auc: 0.9098 - loss: 0.0409 - val_accuracy: 0.5833 - val_auc: 0.8698 - val_loss: 0.1193
# Epoch 1923/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7833 - auc: 0.9045 - loss: 0.0421 - val_accuracy: 0.5833 - val_auc: 0.8812 - val_loss: 0.1196
# Epoch 1924/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8346 - auc: 0.9101 - loss: 0.0404 - val_accuracy: 0.5833 - val_auc: 0.8797 - val_loss: 0.1186
# Epoch 1925/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8189 - auc: 0.9200 - loss: 0.0343 - val_accuracy: 0.5833 - val_auc: 0.8766 - val_loss: 0.1210
# Epoch 1926/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8627 - auc: 0.8999 - loss: 0.0452 - val_accuracy: 0.5833 - val_auc: 0.8690 - val_loss: 0.1216
# Epoch 1927/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7911 - auc: 0.9035 - loss: 0.0495 - val_accuracy: 0.6111 - val_auc: 0.8604 - val_loss: 0.1213
# Epoch 1928/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7988 - auc: 0.9065 - loss: 0.0369 - val_accuracy: 0.6111 - val_auc: 0.8698 - val_loss: 0.1205
# Epoch 1929/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8675 - auc: 0.9086 - loss: 0.0393 - val_accuracy: 0.6111 - val_auc: 0.8788 - val_loss: 0.1187
# Epoch 1930/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7828 - auc: 0.8979 - loss: 0.0545 - val_accuracy: 0.6111 - val_auc: 0.8728 - val_loss: 0.1173
# Epoch 1931/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8563 - auc: 0.9103 - loss: 0.0382 - val_accuracy: 0.6111 - val_auc: 0.8664 - val_loss: 0.1167
# Epoch 1932/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8087 - auc: 0.9012 - loss: 0.0416 - val_accuracy: 0.6111 - val_auc: 0.8655 - val_loss: 0.1168
# Epoch 1933/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7762 - auc: 0.9092 - loss: 0.0441 - val_accuracy: 0.6111 - val_auc: 0.8673 - val_loss: 0.1178
# Epoch 1934/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8187 - auc: 0.9072 - loss: 0.0400 - val_accuracy: 0.6111 - val_auc: 0.8704 - val_loss: 0.1186
# Epoch 1935/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8235 - auc: 0.9197 - loss: 0.0393 - val_accuracy: 0.6111 - val_auc: 0.8685 - val_loss: 0.1181
# Epoch 1936/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8247 - auc: 0.9194 - loss: 0.0386 - val_accuracy: 0.6111 - val_auc: 0.8667 - val_loss: 0.1184
# Epoch 1937/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8637 - auc: 0.9139 - loss: 0.0370 - val_accuracy: 0.6111 - val_auc: 0.8672 - val_loss: 0.1191
# Epoch 1938/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7894 - auc: 0.9158 - loss: 0.0417 - val_accuracy: 0.6111 - val_auc: 0.8661 - val_loss: 0.1179
# Epoch 1939/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8497 - auc: 0.9145 - loss: 0.0466 - val_accuracy: 0.6111 - val_auc: 0.8708 - val_loss: 0.1173
# Epoch 1940/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8741 - auc: 0.9138 - loss: 0.0337 - val_accuracy: 0.6111 - val_auc: 0.8741 - val_loss: 0.1171
# Epoch 1941/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7860 - auc: 0.9112 - loss: 0.0441 - val_accuracy: 0.6111 - val_auc: 0.8734 - val_loss: 0.1180
# Epoch 1942/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7627 - auc: 0.9092 - loss: 0.0474 - val_accuracy: 0.6111 - val_auc: 0.8749 - val_loss: 0.1187
# Epoch 1943/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8604 - auc: 0.9131 - loss: 0.0421 - val_accuracy: 0.5833 - val_auc: 0.8706 - val_loss: 0.1199
# Epoch 1944/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7880 - auc: 0.9075 - loss: 0.0430 - val_accuracy: 0.5833 - val_auc: 0.8647 - val_loss: 0.1209
# Epoch 1945/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8633 - auc: 0.8920 - loss: 0.0416 - val_accuracy: 0.5833 - val_auc: 0.8689 - val_loss: 0.1211
# Epoch 1946/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7999 - auc: 0.9071 - loss: 0.0432 - val_accuracy: 0.5833 - val_auc: 0.8773 - val_loss: 0.1205
# Epoch 1947/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8218 - auc: 0.9141 - loss: 0.0376 - val_accuracy: 0.6111 - val_auc: 0.8739 - val_loss: 0.1198
# Epoch 1948/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8358 - auc: 0.9087 - loss: 0.0389 - val_accuracy: 0.6111 - val_auc: 0.8789 - val_loss: 0.1198
# Epoch 1949/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8164 - auc: 0.9118 - loss: 0.0430 - val_accuracy: 0.6111 - val_auc: 0.8757 - val_loss: 0.1195
# Epoch 1950/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7911 - auc: 0.9155 - loss: 0.0360 - val_accuracy: 0.6111 - val_auc: 0.8725 - val_loss: 0.1184
# Epoch 1951/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8064 - auc: 0.8976 - loss: 0.0460 - val_accuracy: 0.6111 - val_auc: 0.8712 - val_loss: 0.1179
# Epoch 1952/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8100 - auc: 0.9146 - loss: 0.0366 - val_accuracy: 0.6111 - val_auc: 0.8722 - val_loss: 0.1182
# Epoch 1953/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8424 - auc: 0.9040 - loss: 0.0357 - val_accuracy: 0.6111 - val_auc: 0.8760 - val_loss: 0.1188
# Epoch 1954/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8112 - auc: 0.9126 - loss: 0.0394 - val_accuracy: 0.6111 - val_auc: 0.8763 - val_loss: 0.1192
# Epoch 1955/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8197 - auc: 0.9216 - loss: 0.0369 - val_accuracy: 0.6111 - val_auc: 0.8751 - val_loss: 0.1191
# Epoch 1956/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8278 - auc: 0.9101 - loss: 0.0398 - val_accuracy: 0.5833 - val_auc: 0.8736 - val_loss: 0.1190
# Epoch 1957/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8238 - auc: 0.9140 - loss: 0.0410 - val_accuracy: 0.6111 - val_auc: 0.8781 - val_loss: 0.1185
# Epoch 1958/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8264 - auc: 0.9123 - loss: 0.0385 - val_accuracy: 0.5833 - val_auc: 0.8748 - val_loss: 0.1187
# Epoch 1959/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8161 - auc: 0.9147 - loss: 0.0373 - val_accuracy: 0.6111 - val_auc: 0.8727 - val_loss: 0.1187
# Epoch 1960/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8343 - auc: 0.9096 - loss: 0.0394 - val_accuracy: 0.6111 - val_auc: 0.8730 - val_loss: 0.1179
# Epoch 1961/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7473 - auc: 0.8951 - loss: 0.0441 - val_accuracy: 0.5833 - val_auc: 0.8800 - val_loss: 0.1178
# Epoch 1962/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8414 - auc: 0.9044 - loss: 0.0380 - val_accuracy: 0.6111 - val_auc: 0.8767 - val_loss: 0.1182
# Epoch 1963/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8216 - auc: 0.9039 - loss: 0.0379 - val_accuracy: 0.6111 - val_auc: 0.8817 - val_loss: 0.1178
# Epoch 1964/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8210 - auc: 0.9135 - loss: 0.0412 - val_accuracy: 0.6111 - val_auc: 0.8801 - val_loss: 0.1179
# Epoch 1965/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8225 - auc: 0.9048 - loss: 0.0404 - val_accuracy: 0.6111 - val_auc: 0.8712 - val_loss: 0.1183
# Epoch 1966/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8184 - auc: 0.9060 - loss: 0.0412 - val_accuracy: 0.6111 - val_auc: 0.8668 - val_loss: 0.1179
# Epoch 1967/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8319 - auc: 0.9062 - loss: 0.0459 - val_accuracy: 0.6111 - val_auc: 0.8699 - val_loss: 0.1188
# Epoch 1968/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8775 - auc: 0.9072 - loss: 0.0383 - val_accuracy: 0.6111 - val_auc: 0.8706 - val_loss: 0.1179
# Epoch 1969/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8411 - auc: 0.9065 - loss: 0.0438 - val_accuracy: 0.6111 - val_auc: 0.8704 - val_loss: 0.1181
# Epoch 1970/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8254 - auc: 0.9065 - loss: 0.0401 - val_accuracy: 0.6111 - val_auc: 0.8719 - val_loss: 0.1185
# Epoch 1971/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7980 - auc: 0.9088 - loss: 0.0410 - val_accuracy: 0.6111 - val_auc: 0.8718 - val_loss: 0.1190
# Epoch 1972/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8168 - auc: 0.9194 - loss: 0.0354 - val_accuracy: 0.6111 - val_auc: 0.8689 - val_loss: 0.1191
# Epoch 1973/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7959 - auc: 0.9148 - loss: 0.0382 - val_accuracy: 0.6111 - val_auc: 0.8677 - val_loss: 0.1198
# Epoch 1974/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8484 - auc: 0.9057 - loss: 0.0413 - val_accuracy: 0.6111 - val_auc: 0.8667 - val_loss: 0.1206
# Epoch 1975/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8014 - auc: 0.9134 - loss: 0.0417 - val_accuracy: 0.6111 - val_auc: 0.8713 - val_loss: 0.1204
# Epoch 1976/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8193 - auc: 0.9028 - loss: 0.0459 - val_accuracy: 0.6111 - val_auc: 0.8738 - val_loss: 0.1219
# Epoch 1977/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8377 - auc: 0.9134 - loss: 0.0383 - val_accuracy: 0.6111 - val_auc: 0.8685 - val_loss: 0.1253
# Epoch 1978/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7956 - auc: 0.9189 - loss: 0.0406 - val_accuracy: 0.5833 - val_auc: 0.8661 - val_loss: 0.1247
# Epoch 1979/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7724 - auc: 0.8968 - loss: 0.0539 - val_accuracy: 0.5833 - val_auc: 0.8645 - val_loss: 0.1223
# Epoch 1980/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8207 - auc: 0.8930 - loss: 0.0404 - val_accuracy: 0.5833 - val_auc: 0.8705 - val_loss: 0.1202
# Epoch 1981/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8280 - auc: 0.9195 - loss: 0.0418 - val_accuracy: 0.6111 - val_auc: 0.8758 - val_loss: 0.1199
# Epoch 1982/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7827 - auc: 0.8916 - loss: 0.0477 - val_accuracy: 0.6111 - val_auc: 0.8810 - val_loss: 0.1197
# Epoch 1983/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8566 - auc: 0.9116 - loss: 0.0397 - val_accuracy: 0.6111 - val_auc: 0.8834 - val_loss: 0.1189
# Epoch 1984/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7648 - auc: 0.9170 - loss: 0.0427 - val_accuracy: 0.6111 - val_auc: 0.8761 - val_loss: 0.1200
# Epoch 1985/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8553 - auc: 0.8972 - loss: 0.0407 - val_accuracy: 0.6111 - val_auc: 0.8824 - val_loss: 0.1204
# Epoch 1986/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8290 - auc: 0.9072 - loss: 0.0433 - val_accuracy: 0.6111 - val_auc: 0.8803 - val_loss: 0.1207
# Epoch 1987/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7999 - auc: 0.9004 - loss: 0.0426 - val_accuracy: 0.5833 - val_auc: 0.8805 - val_loss: 0.1219
# Epoch 1988/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8332 - auc: 0.9197 - loss: 0.0380 - val_accuracy: 0.5833 - val_auc: 0.8742 - val_loss: 0.1224
# Epoch 1989/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8482 - auc: 0.9180 - loss: 0.0378 - val_accuracy: 0.6111 - val_auc: 0.8776 - val_loss: 0.1208
# Epoch 1990/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7875 - auc: 0.9178 - loss: 0.0371 - val_accuracy: 0.6111 - val_auc: 0.8786 - val_loss: 0.1197
# Epoch 1991/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8468 - auc: 0.9091 - loss: 0.0377 - val_accuracy: 0.6111 - val_auc: 0.8758 - val_loss: 0.1187
# Epoch 1992/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8547 - auc: 0.9053 - loss: 0.0394 - val_accuracy: 0.6111 - val_auc: 0.8788 - val_loss: 0.1183
# Epoch 1993/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7856 - auc: 0.9017 - loss: 0.0450 - val_accuracy: 0.6111 - val_auc: 0.8824 - val_loss: 0.1186
# Epoch 1994/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8414 - auc: 0.9166 - loss: 0.0368 - val_accuracy: 0.6111 - val_auc: 0.8813 - val_loss: 0.1185
# Epoch 1995/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8461 - auc: 0.9203 - loss: 0.0395 - val_accuracy: 0.6111 - val_auc: 0.8776 - val_loss: 0.1185
# Epoch 1996/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7578 - auc: 0.9026 - loss: 0.0378 - val_accuracy: 0.6111 - val_auc: 0.8756 - val_loss: 0.1175
# Epoch 1997/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8009 - auc: 0.9075 - loss: 0.0410 - val_accuracy: 0.6111 - val_auc: 0.8719 - val_loss: 0.1176
# Epoch 1998/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7321 - auc: 0.9057 - loss: 0.0495 - val_accuracy: 0.6111 - val_auc: 0.8769 - val_loss: 0.1176
# Epoch 1999/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8229 - auc: 0.9121 - loss: 0.0384 - val_accuracy: 0.5833 - val_auc: 0.8783 - val_loss: 0.1189
# Epoch 2000/2000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8346 - auc: 0.9215 - loss: 0.0348 - val_accuracy: 0.5833 - val_auc: 0.8784 - val_loss: 0.1200
#
# Standard Autoencoder training complete.
#
# --- Anomaly Detection and Evaluation (Fixed-Size Feature Vectors) ---
# Determined feature dimension from data: 2048
#
# Calculating reconstruction errors for training data...
# Reconstruction errors calculated for training data.
# Determined feature dimension from data: 2048
# Calculating reconstruction errors for test data...
# Reconstruction errors calculated for test data.
# Anomaly Threshold (95th percentile of real train errors): 0.0560
#
# Autoencoder-based Deepfake Detection Evaluation on Testing Set:
# Accuracy: 0.875
# AUC: 0.8849999999999999
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Fake       0.83      0.95      0.88        20
#         Real       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
#
# Confusion Matrix:
# [[19  1]
#  [ 4 16]]
# --- Standard Autoencoder Workflow Complete ---

# %%
autoencoder.save("C:\\Users\\Odwitiyo\\Downloads\\autoencoder.keras")
